# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
sentence = "The bank can be found near the river bank."
tokens = word_tokenize(sentence)

# %%
def find_synonyms(word):
    synonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.append(lemma.name())
    return set(synonyms)

ambiguous_word = "bank"

ambiguous_word_synonyms = find_synonyms(ambiguous_word)
print("Synonyms of 'bank' in various contexts:")
for syn in ambiguous_word_synonyms:
    print(syn)
# Out:
# Synonyms of 'bank' in various contexts:
# bank_building
# banking_company
# coin_bank
# bank
# cant
# money_box
# depository_financial_institution
# rely
# banking_concern
# camber
# swear
# deposit
# savings_bank
# trust

# %%
import nltk
from nltk.wsd import lesk
from nltk.tokenize import word_tokenize
nltk.download('all')
# Out:
# [nltk_data] Downloading collection 'all'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package alpino to /root/nltk_data...
# [nltk_data]    |   Unzipping corpora/alpino.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data]    | Downloading package averaged_perceptron_tagger_ru to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping
# [nltk_data]    |       taggers/averaged_perceptron_tagger_ru.zip.
# [nltk_data]    | Downloading package basque_grammars to
# [nltk_data]    |     /root/nltk_data...
# [nltk_data]    |   Unzipping grammars/basque_grammars.zip.
# [nltk_data]    | Downloading package bcp47 to /root/nltk_data...
# [nltk_data]    | Downloading package biocreative_ppi to
# ...

# %%
def get_semantic(seq, key_word):
	temp = word_tokenize(seq)
	temp = lesk(temp, key_word)
	return temp.definition()

# %%
keyword = 'book'
seq1 = 'I love reading books on coding.'
seq2 = 'The table was already booked by someone else.'

print(get_semantic(seq1, keyword))
print(get_semantic(seq2, keyword))
# Out:
# a number of sheets (ticket or stamps etc.) bound together on one edge
# arrange for and reserve (something for someone else) in advance

# %%
find_synonyms(keyword)
# Out:
# {'Bible',
#  'Book',
#  'Christian_Bible',
#  'Good_Book',
#  'Holy_Scripture',
#  'Holy_Writ',
#  'Koran',
#  'Quran',
#  'Scripture',
#  'Word',
#  'Word_of_God',
#  'account_book',
#  "al-Qur'an",
#  'book',
#  'book_of_account',
#  'hold',
#  'ledger',
#  'leger',
#  'playscript',
#  'record',
#  'record_book',
#  'reserve',
#  'rule_book',
#  'script',
#  'volume'}

# %%
sentence = "The Bank can be found near the river bank."
get_semantic(sentence,'Bank')
# Out:
# 'be in the banking business'

# %%
keyword = 'book'
seq1 = 'I love reading books on coding.'
seq2 = 'The table was already booked by someone else.'

print(get_semantic(seq1, keyword))
print(get_semantic(seq2, keyword))
